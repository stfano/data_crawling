# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
subway1 = pd.read_csv('Subway_201601.csv', encoding='cp949')

# %%
subway2 = pd.read_csv('Subway_201602.csv', encoding='cp949')
subway3 = pd.read_csv('Subway_201603.csv', encoding='cp949')
subway4 = pd.read_csv('Subway_201604.csv', encoding='cp949')
subway5 = pd.read_csv('Subway_201605.csv', encoding='cp949')
subway6 = pd.read_csv('Subway_201606.csv', encoding='cp949')
subway7 = pd.read_csv('Subway_201607.csv', encoding='cp949')
subway8 = pd.read_csv('Subway_201608.csv', encoding='cp949')
subway9 = pd.read_csv('Subway_201609.csv', encoding='cp949')
subway10 = pd.read_csv('Subway_201610.csv', encoding='cp949')
subway11 = pd.read_csv('Subway_201611.csv', encoding='cp949')
subway12 = pd.read_csv('Subway_201612.csv', encoding='cp949')

# %%
subway1.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
subway2.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
subway3.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
subway4.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
subway5.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
subway5.shape, subway6.shape,subway7.shape, subway8.shape,subway9.shape
# Out:
# ((52986, 29), (7140, 24), (7378, 24), (7378, 24), (7140, 24))

# %%
subway5.rename(columns=lambda x: x.replace(' ', ''), inplace=True)

# %%
subway1.rename(columns=lambda x: x.replace(' ', ''), inplace=True)
subway2.rename(columns=lambda x: x.replace(' ', ''), inplace=True)
subway3.rename(columns=lambda x: x.replace(' ', ''), inplace=True)
subway4.rename(columns=lambda x: x.replace(' ', ''), inplace=True)

# %%
subway12.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06시', '06~07시', '07~08시', '08~09시', '09~10시',
#        '10~11시', '11~12시', '12~13시', '13~14시', '14~15시', '15~16시', '16~17시',
#        '17~18시', '18~19시', '19~20시', '20~21시', '21~22시', '22~23시', '23~24시',
#        '00~01시', '01~02시'],
#       dtype='object')

# %%
subway12.rename(columns=lambda x: x.replace('시', ''), inplace=True)

# %%
subway12.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
common_columns = list(set(subway5.columns) & set(subway6.columns))
subway5 = subway5[common_columns]

common_columns = list(set(subway4.columns) & set(subway6.columns))
subway4 = subway4[common_columns]

common_columns = list(set(subway3.columns) & set(subway6.columns))
subway3 = subway3[common_columns]

common_columns = list(set(subway2.columns) & set(subway6.columns))
subway2 = subway2[common_columns]

common_columns = list(set(subway1.columns) & set(subway6.columns))
subway1 = subway1[common_columns]

# %%
subway5.columns
# Out:
# Index(['01~02', '09~10', '13~14', '구분', '23~24', '날짜', '06~07', '16~17', '역명',
#        '08~09', '00~01', '05~06', '19~20', '20~21', '22~23', '21~22', '14~15',
#        '11~12', '10~11', '07~08', '12~13', '18~19', '17~18', '15~16'],
#       dtype='object')

# %%
subway4.columns
# Out:
# Index(['01~02', '09~10', '13~14', '구분', '23~24', '날짜', '06~07', '16~17', '역명',
#        '08~09', '00~01', '05~06', '19~20', '20~21', '22~23', '21~22', '14~15',
#        '11~12', '10~11', '07~08', '12~13', '18~19', '17~18', '15~16'],
#       dtype='object')

# %%
subway4
# Out:
#        01~02  09~10  13~14  구분  23~24          날짜  06~07  16~17        역명  \
# 0          0   2166   2891  승차   2054  2016-04-01    418   3806  서울역(150)
# 1          0     34     12  승차     14  2016-04-01      2     42  서울역(150)
# 2          0    141    112  승차     98  2016-04-01     25    205  서울역(150)
# 3          0      0      0  승차      0  2016-04-01      0      1  서울역(150)
# 4          0    362    683  승차     84  2016-04-01    121    770  서울역(150)
# ...      ...    ...    ...  ..    ...         ...    ...    ...       ...
# 51913      0     39     45  승차      1  2016-04-30      4     31  남태령(434)
# 51914      0     41     40  하차     18  2016-04-30     27     45  남태령(434)
# 51915      0      0      2  하차      0  2016-04-30      0      2  남태령(434)
# 51916      0      5      2  하차      0  2016-04-30      0      0  남태령(434)
# 51917      0     19     18  하차      2  2016-04-30     12     21  남태령(434)
#
#        08~09  ...  22~23  21~22  14~15  11~12  10~11  07~08  12~13  18~19  \
# ...

# %%
df_list = [subway1, subway2, subway3, subway4, subway5, subway6, subway7, subway8, subway9, subway10, subway11, subway12]
merged_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
merged_df.set_index('날짜', inplace=True)

# %%
merged_df.columns
# Out:
# Index(['01~02', '09~10', '13~14', '구분', '23~24', '06~07', '16~17', '역명',
#        '08~09', '00~01', '05~06', '19~20', '20~21', '22~23', '21~22', '14~15',
#        '11~12', '10~11', '07~08', '12~13', '18~19', '17~18', '15~16'],
#       dtype='object')

# %%
desired_columns = ['역명', '구분', '00~01', '01~02', '02~03', '03~04', '04~05', '05~06', '06~07',
                  '07~08', '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16',
                  '16~17', '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24']

merged_df = merged_df.reindex(columns=desired_columns)

# %%
merged_df
# Out:
#                   역명  구분  00~01  01~02  02~03  03~04  04~05  05~06  06~07  \
# 날짜
# 2016-01-01  서울역(150)  승차     52      0    NaN    NaN    NaN    298    243
# 2016-01-01  서울역(150)  승차      0      0    NaN    NaN    NaN      4      0
# 2016-01-01  서울역(150)  승차      1      0    NaN    NaN    NaN     33     15
# 2016-01-01  서울역(150)  승차      0      0    NaN    NaN    NaN      0      0
# 2016-01-01  서울역(150)  승차      4      0    NaN    NaN    NaN     70     78
# ...              ...  ..    ...    ...    ...    ...    ...    ...    ...
# 2016-12-29  남태령(434)  하차     17      0    NaN    NaN    NaN      2     26
# 2016-12-30  남태령(434)  승차      1      0    NaN    NaN    NaN     18     23
# 2016-12-30  남태령(434)  하차     14      0    NaN    NaN    NaN      4     39
# 2016-12-31  남태령(434)  승차      0      0    NaN    NaN    NaN     16     22
# 2016-12-31  남태령(434)  하차      5      0    NaN    NaN    NaN      0     17
#
#             07~08  ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  \
# ...

# %%
merged_df['역명'].value_counts()[70:100]
# Out:
# 역명
# 당산(237)       2502
# 문래(235)       2496
# 용두(250)       2472
# 한양대(209)      2470
# 사당(433)       2468
# 옥수(325)       2454
# 연신내(311)      2448
# 노원(411)       2448
# 구의(213)       2448
# 상왕십리(207)     2438
# 홍제(314)       2426
# 대림(233)       2424
# 총신대입구(432)    2410
# 교대(330)       2386
# 미아(415)       2370
# 낙성대(227)      2366
# 뚝섬(210)       2358
# 봉천(229)       2338
# 독립문(316)      2310
# 불광(312)       2264
# 방배(225)       2256
# 쌍문(413)       2256
# 동작(431)       2222
# 신대방(231)      2192
# 가락시장(340)     2174
# 창동(412)       2168
# 녹번(313)       2160
# 대치(335)       2104
# 구파발(310)      2086
# 잠원(328)       2046
# Name: count, dtype: int64

# %%
merged_df.isnull().sum()
# Out:
# 역명            0
# 구분            0
# 00~01         0
# 01~02         0
# 02~03    312366
# 03~04    312366
# 04~05    312366
# 05~06         0
# 06~07         0
# 07~08         0
# 08~09         0
# 09~10         0
# 10~11         0
# 11~12         0
# 12~13         0
# 13~14         0
# 14~15         0
# 15~16         0
# 16~17         0
# 17~18         0
# 18~19         0
# 19~20         0
# 20~21         0
# 21~22         0
# 22~23         0
# 23~24         0
# dtype: int64

# %%
merged_df.describe()
# Out:
#                00~01          01~02  02~03  03~04  04~05          05~06  \
# count  312366.000000  312366.000000    0.0    0.0    0.0  312366.000000
# mean       41.450369       1.656425    NaN    NaN    NaN      50.109753
# std       137.845612      17.112434    NaN    NaN    NaN     152.140222
# min         0.000000       0.000000    NaN    NaN    NaN       0.000000
# 25%         0.000000       0.000000    NaN    NaN    NaN       0.000000
# 50%         0.000000       0.000000    NaN    NaN    NaN       1.000000
# 75%        11.000000       0.000000    NaN    NaN    NaN      34.000000
# max     13336.000000    2261.000000    NaN    NaN    NaN    4941.000000
#
#                06~07          07~08          08~09          09~10  ...  \
# count  312366.000000  312366.000000  312366.000000  312366.000000  ...
# mean      145.012834     369.277700     641.770193     446.556056  ...
# std       337.766915     997.107581    1788.611771    1121.942723  ...
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
merged_df['18~19']
# Out:
# 날짜
# 2016-01-01    2520
# 2016-01-01      70
# 2016-01-01     139
# 2016-01-01       0
# 2016-01-01     284
#               ...
# 2016-12-29      67
# 2016-12-30     275
# 2016-12-30      81
# 2016-12-31     307
# 2016-12-31      71
# Name: 18~19, Length: 312366, dtype: int64

# %%
sorted_df = merged_df.sort_values(by='18~19')
sorted_df
# Out:
#                         역명  구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 날짜
# 2016-04-13      서울대입구(228)  하차      0      0    NaN    NaN    NaN      0
# 2016-02-20        신용산(429)  하차      0      0    NaN    NaN    NaN      0
# 2016-02-20        신용산(429)  하차      0      0    NaN    NaN    NaN      0
# 2016-02-20        신용산(429)  하차      0      0    NaN    NaN    NaN      0
# 2016-04-06  동대문역사문화공원(422)  승차      0      0    NaN    NaN    NaN      0
# ...                    ...  ..    ...    ...    ...    ...    ...    ...
# 2016-07-13         강남(222)  승차   1109      1    NaN    NaN    NaN    523
# 2016-12-03         시청(151)  하차    115     19    NaN    NaN    NaN     66
# 2016-12-23         강남(222)  승차   2360      5    NaN    NaN    NaN    567
# 2016-07-15         강남(222)  승차   1876      0    NaN    NaN    NaN    562
# 2016-07-08         강남(222)  승차   1833      0    NaN    NaN    NaN    487
#
#             06~07  07~08  ...  14~15  15~16  16~17  17~18  18~19  19~20  \
# ...

# %%
hongje_rows = merged_df[merged_df['역명'] == '홍제(314)']
hongje_rows
# Out:
#                  역명  구분  00~01  01~02  02~03  03~04  04~05  05~06  06~07  \
# 날짜
# 2016-01-01  홍제(314)  승차      0      0    NaN    NaN    NaN     92    200
# 2016-01-01  홍제(314)  승차      0      0    NaN    NaN    NaN      0      0
# 2016-01-01  홍제(314)  승차      0      0    NaN    NaN    NaN     10      7
# 2016-01-01  홍제(314)  승차      0      0    NaN    NaN    NaN     90     66
# 2016-01-01  홍제(314)  승차      0      0    NaN    NaN    NaN      0      0
# ...             ...  ..    ...    ...    ...    ...    ...    ...    ...
# 2016-12-29  홍제(314)  하차    319      0    NaN    NaN    NaN     44    313
# 2016-12-30  홍제(314)  승차     42      0    NaN    NaN    NaN    324    791
# 2016-12-30  홍제(314)  하차    368      0    NaN    NaN    NaN     44    289
# 2016-12-31  홍제(314)  승차     94     26    NaN    NaN    NaN    277    392
# 2016-12-31  홍제(314)  하차    320    504    NaN    NaN    NaN     25    252
#
#             07~08  ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  \
# ...

# %%
merged_df.reset_index(inplace=True)

# %%
merged_df
# Out:
#                 날짜        역명  구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0       2016-01-01  서울역(150)  승차     52      0    NaN    NaN    NaN    298
# 1       2016-01-01  서울역(150)  승차      0      0    NaN    NaN    NaN      4
# 2       2016-01-01  서울역(150)  승차      1      0    NaN    NaN    NaN     33
# 3       2016-01-01  서울역(150)  승차      0      0    NaN    NaN    NaN      0
# 4       2016-01-01  서울역(150)  승차      4      0    NaN    NaN    NaN     70
# ...            ...       ...  ..    ...    ...    ...    ...    ...    ...
# 312361  2016-12-29  남태령(434)  하차     17      0    NaN    NaN    NaN      2
# 312362  2016-12-30  남태령(434)  승차      1      0    NaN    NaN    NaN     18
# 312363  2016-12-30  남태령(434)  하차     14      0    NaN    NaN    NaN      4
# 312364  2016-12-31  남태령(434)  승차      0      0    NaN    NaN    NaN     16
# 312365  2016-12-31  남태령(434)  하차      5      0    NaN    NaN    NaN      0
#
# ...

# %%
merged_df.fillna(0, inplace=True)

# %%
time_columns = ['00~01', '01~02', '02~03', '03~04', '04~05', '05~06', '06~07', 
                '07~08', '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', 
                '14~15', '15~16', '16~17', '17~18', '18~19', '19~20', '20~21', 
                '21~22', '22~23', '23~24']

merged_df['time_Total'] = merged_df[time_columns].sum(axis=1)

# %%
merged_df['날짜'] = pd.to_datetime(merged_df['날짜'])

merged_df['연도'] = merged_df['날짜'].dt.year
merged_df['월'] = merged_df['날짜'].dt.month
merged_df['일'] = merged_df['날짜'].dt.day

# %%
new_df = merged_df[['역명','연도', '월', '일', 'time_Total']].copy()

# %%
new_df = new_df.sort_values(by='time_Total', ascending=False)

# %%
new_df
# Out:
#                 역명    연도   월   일  time_Total
# 270511     강남(222)  2016   7   8    141617.0
# 270510     강남(222)  2016   7   8    137744.0
# 270539     강남(222)  2016   7  22    136569.0
# 270525     강남(222)  2016   7  15    136119.0
# 308011   홍대입구(239)  2016  12  24    134556.0
# ...            ...   ...  ..  ..         ...
# 25971   종합운동장(218)  2016   1  16         0.0
# 88229    홍대입구(239)  2016   2  21         0.0
# 190833  미아사거리(416)  2016   4  20         0.0
# 26003      선릉(220)  2016   1  16         0.0
# 114803     교대(223)  2016   3   8         0.0
#
# [312366 rows x 5 columns]
